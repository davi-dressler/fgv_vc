# %%
import cv2 as cv

imagem = cv.imread(".\PoucoContraste.png")

def aumentar_brilho(imagem, alpha: float, beta: float):
    
    #Aumenta o brilho
    pass

# imagem_brilho = aumentar_brilho(imagem, 0)
# print(imagem_brilho)
# cv.imshow("Janela", imagem_brilho)
# cv.waitKey(0)
# cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 10
#       5 def aumentar_brilho(imagem, alpha: float, beta: float):
#       6
#       7     #Aumenta o brilho
#       8     pass
# ---> 10 imagem_brilho = aumentar_brilho(imagem, 0)
#      11 print(imagem_brilho)
#      12 cv.imshow("Janela", imagem_brilho)
#
# TypeError: aumentar_brilho() missing 1 required positional argument: 'beta'

# %%
img = cv.imread("..\imagens\messi5.jpg")

ball = img[280:340, 330:390]
img[273:333, 100:160] = ball

cv.imwrite('messi_bola_ducplicada.png', imagem)

cv.imshow("Janela", img)
cv.waitKey(0)
cv.destroyAllWindows()
